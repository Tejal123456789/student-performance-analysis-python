# %%
import pandas as pd

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Tejal'

# %%
df = pd.read_csv(r"C:\Users\Tejal\OneDrive\Apps\Projects\student_data_cleaned.csv")

# %%
df.head()
# Out:
#    student_id   age gender academic_level  study_hours  self_study_hours  \
# 0         1.0  18.0  Other    High School         7.64              1.56
# 1         2.0  18.0  Other    High School         2.21              2.22
# 2         3.0  22.0   Male    High School         3.45              0.00
# 3         4.0  17.0  Other    High School         5.75              2.08
# 4         5.0  19.0  Other    High School         6.83              1.72
#
#    online_classes_hours  social_media_hours  gaming_hours  sleep_hours  ...  \
# 0                  2.20                3.05          2.19         6.52  ...
# 1                  2.10                1.65          2.55         5.97  ...
# 2                  0.29                1.34          2.08         8.39  ...
# 3                  3.01                2.27          2.20         6.31  ...
# 4                  3.33                2.65          0.70         8.01  ...
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   student_id               5000 non-null   float64
#  1   age                      5000 non-null   float64
#  2   gender                   5000 non-null   object
#  3   academic_level           5000 non-null   object
#  4   study_hours              5000 non-null   float64
#  5   self_study_hours         5000 non-null   float64
#  6   online_classes_hours     5000 non-null   float64
#  7   social_media_hours       5000 non-null   float64
#  8   gaming_hours             5000 non-null   float64
#  9   sleep_hours              5000 non-null   float64
#  10  screen_time_hours        5000 non-null   float64
#  11  exercise_minutes         5000 non-null   float64
#  12  caffeine_intake_mg       5000 non-null   float64
# ...

# %%
    df.describe()
# Out:
#         student_id          age  study_hours  self_study_hours  \
# count  5000.000000  5000.000000  5000.000000       5000.000000
# mean   2500.500000    20.520400     4.539594          2.478734
# std    1443.520003     2.870406     1.821665          1.177990
# min       1.000000    16.000000     0.000000          0.000000
# 25%    1250.750000    18.000000     3.250000          1.660000
# 50%    2500.500000    20.000000     4.530000          2.480000
# 75%    3750.250000    23.000000     5.760000          3.290000
# max    5000.000000    25.000000    11.840000          7.410000
#
#        online_classes_hours  social_media_hours  gaming_hours  sleep_hours  \
# count           5000.000000         5000.000000   5000.000000  5000.000000
# mean               2.011984            2.998086      1.564514     7.016492
# std                0.983906            1.467949      1.110807     1.163692
# min                0.000000            0.000000      0.000000     4.000000
# ...

# %%
df.isnull().sum()
# Out:
# student_id                 0
# age                        0
# gender                     0
# academic_level             0
# study_hours                0
# self_study_hours           0
# online_classes_hours       0
# social_media_hours         0
# gaming_hours               0
# sleep_hours                0
# screen_time_hours          0
# exercise_minutes           0
# caffeine_intake_mg         0
# part_time_job              0
# upcoming_deadline          0
# internet_quality           0
# mental_health_score        0
# focus_index                0
# burnout_level              0
# productivity_score         0
# exam_score                 0
# Total Screen Time Check    0
# dtype: int64

# %%
df["exam_score"].mean()
# Out:
# 18.803752000000003

# %%
df.groupby("gender")["exam_score"].mean()
# Out:
# gender
# Female    19.024742
# Male      18.919180
# Other     18.465391
# Name: exam_score, dtype: float64

# %%
df.groupby("academic_level")["exam_score"].mean()
# Out:
# academic_level
# High School      18.809970
# Postgraduate     18.651796
# Undergraduate    18.953632
# Name: exam_score, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df["study_hours"], df["exam_score"])
plt.xlabel("Study Hours")
plt.ylabel("Exam Score")
plt.title("Study Hours vs Exam Score")
plt.show()

# %%
df["exam_score"].max()
# Out:
# 64.09

# %%
df[["sleep_hours", "exam_score"]].corr()
# Out:
#              sleep_hours  exam_score
# sleep_hours      1.00000     0.23471
# exam_score       0.23471     1.00000

# %%
plt.scatter(df["sleep_hours"], df["exam_score"])
plt.xlabel("Sleep Hours")
plt.ylabel("Exam Score")
plt.title("Sleep Hours vs Exam Score")
plt.show()

# %%
df[["burnout_level", "exam_score"]].corr()
# Out:
#                burnout_level  exam_score
# burnout_level       1.000000   -0.407808
# exam_score         -0.407808    1.000000

# %%
plt.scatter(df["burnout_level"], df["exam_score"])
plt.xlabel("Burnout Level")
plt.ylabel("Exam Score")
plt.title("Burnout Level vs Exam Score")
plt.show()

# %%
df[["productivity_score", "exam_score"]].corr()
# Out:
#                     productivity_score  exam_score
# productivity_score            1.000000    0.886401
# exam_score                    0.886401    1.000000

# %%
plt.scatter(df["productivity_score"], df["exam_score"])
plt.xlabel("Productivity Score")
plt.ylabel("Exam Score")
plt.title("Productivity vs Exam Score")
plt.show()

# %%
df[["Total Screen Time Check", "exam_score"]].corr()
# Out:
#                          Total Screen Time Check  exam_score
# Total Screen Time Check                 1.000000   -0.101471
# exam_score                             -0.101471    1.000000

# %%
plt.scatter(df["Total Screen Time Check"], df["exam_score"])
plt.xlabel("Total Screen Time")
plt.ylabel("Exam Score")
plt.title("Screen Time vs Exam Score")
plt.show()

# %%
import seaborn as sns

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.select_dtypes(include='number').corr(), 
            annot=True, 
            cmap="coolwarm")
plt.title("Correlation Matrix")
plt.show()
